# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Parameters:
# - 5 seeds
# - 4*$d$ initial points (latin hypercube)
# - Initial zoom $R$=1, $dR=2$
# - Total budget = 10 + 10*$d$
# - Standardization ON

# %%
syn_path = '/Users/jsull/Documents/berkeley/stats/NFO/plots/standardized/s5_post_'
def show_plot(path_end,path=syn_path):
    plt.figure(figsize=(10,14))
    img = mpimg.imread(path+path_end)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### 20d Uncorrelated Gaussian

# %%
show_plot('ucg20.png')

# %% [markdown]
# ## Correlated Gaussian

# %% [markdown]
# ### 5d

# %%
show_plot('cg5.png')

# %% [markdown]
# ### 10d

# %%
show_plot('cg10.png')

# %% [markdown]
# ## Double Gaussian

# %% [markdown]
# ### 5d

# %%
show_plot('dg5.png')

# %% [markdown]
# ### 10d

# %%
show_plot('dg10.png')

# %% [markdown]
# ## Banana

# %% [markdown]
# ### 2d

# %%
show_plot('ban2.png')

# %% [markdown]
# ### 10d

# %%
show_plot('ban10.png') #some bug here at the end when TuRBO accumulates samples since goes over budget

# %%
show_plot('cc12.png',path='/Users/jsull/Documents/berkeley/stats/NFO/plots/standardized/s5_app_')

# %% [markdown]
# ## Previous unstandardized results

# %% [markdown]
# ### 10d correlated gaussian

# %%
#Not much better than random...
show_plot('cg10.png',path='/Users/jsull/Documents/berkeley/stats/NFO/plots/unstandardized/lN050_s5_post_')
