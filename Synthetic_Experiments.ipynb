# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Parameters:
# - 5 seeds
# - 2*$d$ initial points (latin hypercube)
# - Initial zoom $R$=1, $dR=2$
# - Total budget = 10 + 10*$d$

# %%
syn_path = '/Users/jsull/Documents/berkeley/stats/NFO/plots/unstandardized/s5_syn_'
def show_plot(path_end):
    plt.figure(figsize=(10,14))
    img = mpimg.imread(syn_path+path_end)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Ackley

# %% [markdown]
# ### 2d

# %%
show_plot('ack2.png')

# %% [markdown]
# ### 5d

# %%
show_plot('ack5.png')

# %% [markdown]
# ### 10d

# %%
show_plot('ack10.png')

# %% [markdown]
# ## Rastrigin

# %% [markdown]
# ### 6d

# %%
show_plot('ras6.png')

# %% [markdown]
# ### 10d

# %%
show_plot('ras10.png')
